# %%
import mga
import mga.dataset
import mga.pagerank

# %%
mga.dataset.download_ml_small(force_download=True)
# mga.dataset.download_ml_25m(force_download=True)

# %%
mga.clean()

# %%
# !./cpp/generate ratings.mtx
# Creates edges.csv

# %%
movie_df = mga.pagerank.pagerank_skn(disable_progress_bar=False)
movie_df.to_csv('movies_pr.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

plt.rcParams['figure.figsize'] = (9, 9)

sns.set()

# %%
with open('genre.txt') as file:
    genre_set = set(line.strip() for line in file)

# %%
for genre in genre_set:
    x = np.array(movie_df['pagerank'])
    y = np.array(movie_df[genre] / movie_df['pagerank'])
    plt.scatter(x, y)

    m, b = np.polyfit(x, y, deg=1)
    x_fit = np.array([x.min(), x.max()])
    y_fit = m * x_fit + b
    plt.plot(x_fit, y_fit)

    plt.xlabel('Pagerank')
    plt.ylabel(f'TSPr/Pr ({genre})')
    plt.show()
